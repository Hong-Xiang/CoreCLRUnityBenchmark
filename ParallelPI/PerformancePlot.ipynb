# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Report.csv')

# %%
df['runtime-method'] = df['runtime'] + "-" + df['method']

# %%
def plot_data(group):
    g = sns.catplot(data=df[df['group'] == group], kind="bar", x="runtime", y="normalized time(μs)", hue="method")
    g.set(title=f"{group} group")
    return g

# %%
df[df['group'] == 'middle']
# Out:
#      group  任务大小    任务数    runtime          method  每任务时间(μs）    60帧千任务数  \
# 11  middle  4096  65536    MonoJIT     ParallelFor   2.475128   6.733658
# 12  middle  4096  65536      Burst     ParallelFor   0.406647  40.985616
# 13  middle  4096  65536    MonoJIT            IJob   2.801971   5.948193
# 14  middle  4096  65536      Burst            IJob   0.569153  29.283289
# 15  middle  4096  65536    CoreCLR        Parallel   0.604630  27.565089
# 16  middle  4096  65536    CoreCLR     Task Thread   0.720978  23.116755
# 17  middle  4096  65536    CoreCLR      Task async   0.783920  21.260665
# 18  middle  4096  65536  NativeAOT        Parallel   0.417709  39.900152
# 19  middle  4096  65536  NativeAOT     Task Thread   0.499725  33.351654
# 20  middle  4096  65536  NativeAOT      Task async   0.577927  28.838724
# 21  middle  4096  65536  NativeCPP  std::par_unseq   0.425110  39.205552
#
#     totalTime(ms)  normalized time(μs)            runtime-method
# ...

# %%
plot_data("large")

# %%
plot_data("middle")

# %%
plot_data("small")
